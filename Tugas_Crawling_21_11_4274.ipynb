# %% [markdown]
# <a href="https://colab.research.google.com/github/fhydzaa/Crawling-Comment-Youtube/blob/main/Tugas_Crawling_21_11_4274.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CRAWLING COMMENTS YOUTUBE**
#
# HIGHLIGHT! Indonesia U23 (9) vs (0) China Taipei U23 | AFC U23 ASIAN CUP QATAR 2024

# %%
import os
import googleapiclient.discovery
import csv
import pandas as pd

# %%
# Set API KEY from gooogle cloud APIs & Services
API_KEY = 'AIzaSyAMb6R5B8NEvwz-DX9EJHwbPQU0_cRyG44'

# Initialize the YouTube Data API client
youtube = googleapiclient.discovery.build('youtube', 'v3', developerKey=API_KEY)

# URL of the video you want to crawl this comments
video_url = 'https://www.youtube.com/watch?v=Xsfwy8GQgps'

# Extract the video ID from the URL
video_id = video_url.split('v=')[1]

# Create a CSV file to save the comments
csv_file = open('crawling.csv', 'w', newline='', encoding='utf-8')
csv_writer = csv.writer(csv_file)

# Write header row to the CSV file
csv_writer.writerow(['Author', 'Created At', 'Comment', 'Like Count'])

# Call the API to retrieve the video comments
next_page_token = None

while True:
    request = youtube.commentThreads().list(
        part='snippet',
        videoId=video_id,
        textFormat='plainText',
        maxResults=100,
        pageToken=next_page_token
    )

    response = request.execute()

    for item in response['items']:
        comment_data = item['snippet']['topLevelComment']['snippet']
        comment = comment_data['textDisplay']
        author = comment_data['authorDisplayName']
        created_at = comment_data['publishedAt']
        like_count = comment_data['likeCount']

        # Write comment data to the CSV file
        csv_writer.writerow([author, created_at, comment, like_count])

    next_page_token = response.get('nextPageToken')

    if not next_page_token:
        break

# Close the CSV file
csv_file.close()

print('Comments have been saved to crawling.csv')
# Out:
# Comments have been saved to crawling.csv

# %%
# Show result of crawling in crawling.csv
df = pd.read_csv('crawling.csv')

df.head(50)
# Out:
#                     Author            Created At  \
# 0                  framoro  2023-09-12T22:59:33Z
# 1            TUKANG SAMPEU  2023-09-12T22:55:01Z
# 2             Randy Kusuma  2023-09-12T21:49:31Z
# 3             Raffi Hasyim  2023-09-12T21:28:37Z
# 4             Kastil Besar  2023-09-12T21:22:15Z
# 5              Robiul awal  2023-09-12T20:46:53Z
# 6                @eza_zold  2023-09-12T20:14:30Z
# 7                Animous27  2023-09-12T20:07:49Z
# 8             Feggy Arjono  2023-09-12T18:44:28Z
# 9               Santoso So  2023-09-12T18:38:57Z
# 10                 Er Diey  2023-09-12T18:37:23Z
# 11            Nama Default  2023-09-12T18:12:50Z
# 12             marga nyonk  2023-09-12T17:39:11Z
# 13                  MR 250  2023-09-12T17:37:27Z
# 14          Rizki Setiawan  2023-09-12T16:56:06Z
# 15            Agus Pramono  2023-09-12T16:30:01Z
# 16            Anank Krisna  2023-09-12T16:22:49Z
# 17            Saud Andrico  2023-09-12T16:16:57Z
# ...
